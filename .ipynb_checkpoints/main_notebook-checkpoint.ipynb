# %% [markdown]
# # Use this notbook for your 3 choices of APIs

# %%
#start up ideas generator
# A project to be done with this one is "The creation of an Entrepreneurhip hub"

# %%
import pandas as pd
import requests

# %%
#start up ideas
import pandas as pd
import requests

startup_res = requests.get('http://itsthisforthat.com/api.php?json')

# %%
type(startup_res)
# Out:
# requests.models.Response

# %%
from pandas.io.json import json_normalize

dataX = requests.get('http://itsthisforthat.com/api.php?json').json()
dataX2 = json_normalize(dataX)
dataX2.shape
dataX2
# Out:
# C:\Users\Clement\AppData\Local\Temp\ipykernel_11692\2578082385.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   dataX2 = json_normalize(dataX)
#       this               that
# 0  Soylent  Highway Accidents

# %%
dataX2.columns
# Out:
# Index(['this', 'that'], dtype='object')

# %%
dataX2.shape
# Out:
# (1, 2)

# %%
#Rainviewer
# A project can be "How to predict the weather"

# %%
rain_viewer_res = requests.get('https://api.rainviewer.com/public/weather-maps.json')  
print(rain_viewer_res)
# Out:
# <Response [200]>

# %%
rainviewer = rain_viewer_res.json()
rviewer = json_normalize(rainviewer)
# Out:
# C:\Users\Clement\AppData\Local\Temp\ipykernel_11692\182833484.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   rviewer = json_normalize(rainviewer)

# %%
rviewer.columns
# Out:
# Index(['version', 'generated', 'host', 'radar.past', 'radar.nowcast',
#        'satellite.infrared'],
#       dtype='object')

# %%
rviewer.shape
rviewer
# Out:
#   version   generated                              host  \
# 0     2.0  1673801415  https://tilecache.rainviewer.com
#
#                                           radar.past  \
# 0  [{'time': 1673794200, 'path': '/v2/radar/16737...
#
#                                        radar.nowcast  \
# 0  [{'time': 1673802000, 'path': '/v2/radar/nowca...
#
#                                   satellite.infrared
# 0  [{'time': 1673794200, 'path': '/v2/satellite/4...

# %%
rviewer.shape
rviewer[['radar.past', 'radar.nowcast','satellite.infrared']].head()
# Out:
#                                           radar.past  \
# 0  [{'time': 1673794200, 'path': '/v2/radar/16737...
#
#                                        radar.nowcast  \
# 0  [{'time': 1673802000, 'path': '/v2/radar/nowca...
#
#                                   satellite.infrared
# 0  [{'time': 1673794200, 'path': '/v2/satellite/4...

# %%
#maps = json_normalize(rainviewer['satellite.infrared'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11692\2844262025.py in <module>
# ----> 1 maps = json_normalize(rainviewer['satellite.infrared'])
#
# KeyError: 'satellite.infrared'

# %%
#NBA GAMES
#A project to be created with this API is "Prediction of the Nba finals Winner"

# %%
NBA_games=requests.get('https://www.balldontlie.io/api/v1/games')

# %%
nba = NBA_games.json()
nbadata = json_normalize(nba)
# Out:
# C:\Users\Clement\AppData\Local\Temp\ipykernel_12868\1091701412.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   nbadata = json_normalize(nba)

# %%
nbadata.columns
# Out:
# Index(['data', 'meta.total_pages', 'meta.current_page', 'meta.next_page',
#        'meta.per_page', 'meta.total_count'],
#       dtype='object')

# %%
nbadata.shape
nbadata[['data', 'meta.total_count','meta.per_page']].head(60)
# Out:
#                                                 data  meta.total_count  \
# 0  [{'id': 47179, 'date': '2019-01-30T00:00:00.00...             52485
#
#    meta.per_page
# 0             25

# %%
games = json_normalize(nba['data'])
# Out:
# C:\Users\Clement\AppData\Local\Temp\ipykernel_12868\1345972070.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   games = json_normalize(nba['data'])

# %%
games
# Out:
#        id                      date  home_team_score  period  postseason  \
# 0   47179  2019-01-30T00:00:00.000Z              126       4       False
# 1   48751  2019-02-09T00:00:00.000Z              112       4       False
# 2   48739  2019-02-08T00:00:00.000Z              117       4       False
# 3   48740  2019-02-08T00:00:00.000Z              119       4       False
# 4   48746  2019-02-08T00:00:00.000Z              102       4       False
# 5   48762  2019-02-11T00:00:00.000Z              121       4       False
# 6   48745  2019-02-08T00:00:00.000Z              122       4       False
# 7   48748  2019-02-09T00:00:00.000Z              105       4       False
# 8   48749  2019-02-09T00:00:00.000Z              120       4       False
# 9   48747  2019-02-09T00:00:00.000Z              125       4       False
# 10  48752  2019-02-09T00:00:00.000Z              125       4       False
# 11  48756  2019-02-10T00:00:00.000Z              102       4       False
# ...
